# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
data=np.random.randn(1000)

# %%
data
# Out:
# array([-1.30988583e+00,  1.62655438e-01,  3.72029862e-01,  6.99384814e-01,
#         4.53756288e-01, -5.86836343e-03, -4.62666433e-01,  4.96480679e-01,
#         3.19432645e-01,  1.00917095e+00,  3.46426686e+00, -1.40590574e+00,
#        -1.60201930e+00, -1.18950831e+00, -7.00718991e-01, -1.47440894e+00,
#        -5.09134657e-01, -2.65706111e+00, -8.15344633e-01, -8.34909274e-01,
#        -9.36942699e-01,  2.87478597e-01, -1.25681418e+00, -9.02316670e-01,
#         3.04174616e+00, -1.77453964e+00,  3.12343607e-01, -5.95852934e-01,
#         1.28206997e+00,  1.25933967e+00, -1.30720361e+00, -1.48052853e-01,
#         4.08556479e-01, -3.71219761e-01, -6.99314884e-01, -3.31546269e-01,
#        -5.32116018e-01,  9.73791259e-01, -1.14765789e+00, -8.99312720e-01,
#         2.44731032e-01,  2.12556330e-01,  9.04732316e-01,  4.05855176e-01,
#        -9.70840476e-01, -3.55940274e-01,  1.54967096e-01,  1.71440250e-01,
# ...

# %%
plt.hist(data,bins=30, color='skyblue')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Basic Plot')
plt.show()

# %%
x=[1,2,6,7,8,9,11,12,13,14,15,16,17,18,21,22]
y=[]
for i in x:
    y.append(pow(2,i))
y
# Out:
# [2,
#  4,
#  64,
#  128,
#  256,
#  512,
#  2048,
#  4096,
#  8192,
#  16384,
#  32768,
#  65536,
#  131072,
#  262144,
#  2097152,
#  4194304]

# %%
plt.hist(y,bins=5,color='orange')
plt.xlabel('Ecoli')
plt.ylabel('Frequency')
plt.title('Ecoli ocuurence per minute')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x=np.linspace(0,10,100)
y=np.sin(x)
z=np.cos(x)
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.plot(x,y,z,label='3D Line')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D plot')
plt.show()

# %%
Z=np.linspace(0,3)
X=np.sqrt(8)* np.sin(z)
Y=np.sqrt(8)* np.cos(z)
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.plot(X,Y,Z,label='3D Line')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D plot')
plt.show()

# %%
length=np.sqrt(np.diff(X)**2 + np.diff(Y)**2 + np.diff(Z)**2)

# %%
length[0]
# Out:
# 0.18364797122453475
